# %% [markdown]
# ### [Matplotlib](https://matplotlib.org/stable/tutorials/)

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0, 2, 100)  # Sample data.

fig, ax = plt.subplots(layout='constrained')

ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')

ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title("Simple Plot")
ax.legend()

# pass in x series and y series, not tuples of (x, y)
ax.plot([0, 2], [1, 4])

# %%
x, y = [0, 1, 2, 3], [1, 4, 9, 16]

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')

plt.show()

# %%
plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'bx')
plt.axis((0, 6, 0, 20)) # xmin, xmas, ymin, ymax
plt.show()

# %%
# evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

# red dashes, blue squares and green triangles
plt.plot(t, t, 'r--', t, t**2, 'bs', t, t**3, 'g^')
plt.show()

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure()

plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

# add a line
# plt.plot([0,5], [0, 5], 'k-')

# add a horozonal line
# plt.hlines(0.5, 0, 5)
# add a verticle line
# plt.vlines(1, 0, 1)
# add a diagonal line to (5, 0) from (0, 1)
plt.plot([5, 0], [0, 1])

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')

plt.show()

# %%
# first figure

plt.figure(1)                # the first figure

plt.subplot(211)             # the first subplot in the first figure
plt.plot([1, 2, 3])

plt.subplot(212)             # the second subplot in the first figure
plt.plot([4, 5, 6])

# second figure

plt.figure(2)                # a second figure

plt.plot([4, 5, 6])          # creates a subplot() by default

plt.figure(1)                # first figure current;
                             # subplot(212) still current
plt.subplot(211)             # make subplot(211) in the first figure
                             # current
plt.title('Easy as 1, 2, 3') # subplot 211 title

plt.show()
