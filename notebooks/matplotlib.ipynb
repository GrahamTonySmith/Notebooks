# %% [markdown]
# ### [Matplotlib](https://matplotlib.org/stable/tutorials/)

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2, 3]
y = [1, 4, 9, 16]

# %%
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
